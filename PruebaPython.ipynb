# %% [markdown]
# <a href="https://colab.research.google.com/github/anaavelar123/summercamppruebapython/blob/main/PruebaPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hola")
# Out:
# hola

# %%
jugador = "Linkin"
print(jugador,"Ha entrado a la arena")
jugador2 = "Kirby"
print(jugador2, "se ha caido del escenario")
# Out:
# Linkin Ha entrado a la arena
# Kirby se ha caido del escenario
